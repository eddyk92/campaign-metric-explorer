# %%
import sys, os

# Move up one level from 'notebook/' to the project root
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

from src.campaign_metric_explorer import load_data, compute_metrics

# %%
df = load_data('/Users/kevineddy/Desktop/AI_Data_Projects/campaign-metric-explorer/data/campaign_data_simulated.csv')
df = compute_metrics(df)
df.head()
# Out:
#                   Date   Channel     Campaign  Impressions  Clicks  \
# 0  2025-09-26 12:36:44    TikTok   Campaign_2        13321    3756
# 1  2025-07-06 06:41:18    Google  Campaign_14        33567    1259
# 2  2025-09-27 23:57:30   Twitter  Campaign_16         5418    3274
# 3  2025-09-02 00:03:08  LinkedIn  Campaign_17        43164    4906
# 4  2025-06-04 02:38:12   Twitter  Campaign_11         2986    1409
#
#    Conversions    Spend   Revenue       CTR       CVR       CPC          CPM  \
# 0          117   790.05   1481.49  0.281961  0.031150  0.210343    59.308610
# 1          109  4793.43  20920.95  0.037507  0.086577  3.807331   142.801859
# 2          375   267.18    519.77  0.604282  0.114539  0.081607    49.313400
# 3           67  4872.84  19894.99  0.113660  0.013657  0.993241   112.891298
# 4          455  3317.11  10510.95  0.471869  0.322924  2.354230  1110.887475
#
#        ROAS
# 0  1.875185
# 1  4.364505
# 2  1.945393
# 3  4.082833
# 4  3.168707

# %% [markdown]
# ### Phase 3: Visualization & Interactivity
# Create Interactive Filters
#
# * Sidebar: Select Channel, Date Range, Campaign.
